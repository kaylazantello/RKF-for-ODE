# %%
# import necessary packages
import numpy as np  # import numpy under the name np
from scipy.integrate import odeint  # import the odeint function from scipy integrate package
import matplotlib.pyplot as plt  # import matplotlib pyplot package under the name plt

# define initial conditionals
x0 = 1
y0 = 5

# define step size
h = 0.02

# initialize lists for values of x and y
x = []
y = []

# insert each initial conditional into its respective list
x.append(x0)
y.append(y0)

# define ODE to solve
def func(xi, yi):
    # return value of y'
    #return 2 * xi * yi
    #return (-1 * (3 / xn + yn)) / (3 * xn * yn)
    return yi / (np.exp(xi) - 1)

# define range of n for the solutions (xn, yn) of the ODE
myRange = range(0, 10)  # program will use RKF method to calculate solutions (x0, y0) to (x1000, y1000)

for n in myRange:
    print(" ")
    k1 = func(x[n], y[n])
    print("k1 = " + str(k1))
    #k2 = func(x[n] + h/2, h/2 * k1 + y[n])
    k2 = func(x[n] + h/2, y[n] + h/2 * k1)
    print("k2 = " + str(k2))
    #k3 = func(x[n] + h/2, h/2 * k2 + y[n])
    k3 = func(x[n] + h/2, y[n] + h/2 * k2)
    print("k3 = " + str(k3))
    k4 = func(x[n] + h, y[n] + h * k3)
    print("k4 = " + str(k4))

    x.append(x[n] + h)
    y.append(y[n] + (h/6)*(k1 + 2*k2 + 2*k3 + k4))

    print("x" + str(n+1) + ": " + str(x[n+1]))
    print("y" + str(n+1) + ": " + str(y[n+1]))

#xp = np.linspace(0, 10)
plt.plot(x, y)
plt.show()
# Out:
#
# k1 = 2.9098835343466325
# k2 = 2.881012781316887
# k3 = 2.8808473898397886
# k4 = 2.8522625097818235
# x1: 1.02
# y1: 5.057619554621473
#
# k1 = 2.852263979910616
# k2 = 2.8239623985040883
# k3 = 2.823805260542436
# k4 = 2.7957839992239633
# x2: 1.04
# y2: 5.114098165612232
#
# k1 = 2.7957853690887142
# k2 = 2.768041840205368
# k3 = 2.7678924928461486
# k4 = 2.740423832257545
# x3: 1.06
# y3: 5.169458425170396
#
# k1 = 2.740425109684549
# k2 = 2.7132287237749253
# k3 = 2.713086734232331
# k4 = 2.686159864741147
# x4: 1.08
# y4: 5.22372247813853
#
# k1 = 2.686161056857085
# k2 = 2.6595011106490527
# k3 = 2.6593660739457974
# k4 = 2.6329703909592297
# x5: 1.1
# y5: 5.276912030861883
#
# k1 = 2.6329715042624247
# k2 = 2.606837497468389
# k3 = 2.606709034328042
# k4 = 2.580834134947519
# x6: 1.12
# y6: 5.3290483598712255
#
# k1 = 2.580835175370992
# k2 = 2.5552168073853085
# k3 = 2.555094562313255
# k4 = 2.529730241989266
# x7: 1.1400000000000001
# y7: 5.3801523203937505
#
# k1 = 2.5297312149566533
# k2 = 2.5046183815515963
# k3 = 2.504502021084966
# k4 = 2.4796382702791324
# x8: 1.1600000000000001
# y8: 5.430244354695446
#
# k1 = 2.479639180754359
# k2 = 2.4550219707818446
# k3 = 2.454911181891073
# k4 = 2.430538182751476
# x9: 1.1800000000000002
# y9: 5.479344500258286
#
# k1 = 2.4305390352829743
# k2 = 2.406407727388219
# k3 = 2.4063022160149594
# k4 = 2.3824103390698967
# x10: 1.2000000000000002
# y10: 5.527472397795483

# %%
# define function to calculate given derivative
def model(yi, xi):
    return 2 * xi * yi
    #return (-1 * (3 / xi + yi)) / (3 * xi * yi)

# create array for x values to report solution at
xr = np.linspace(1, 2, 10)
yinit = 1.0

ys = odeint(model, yinit, xr)

plt.plot(xr, ys)
#plt.ylim(-0.2, 1.0)
plt.show()

# %%
plt.plot(xr, ys)
plt.plot(x, y, 'x')
